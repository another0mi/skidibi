# %%
# !sudo apt update && sudo apt upgrade
# !sudo apt autoremove
# !pip install yt-dlp
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [783 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [2,104 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,641 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,920 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [61.2 kB]
# ...

# %%
# !yt-dlp -o "sus/%(playlist_index)s-%(title)s.%(ext)s" "https://www.youtube.com/playlist?list=PL3BHAe3X0TGvUFmKDKPnHSf5s_HSv3HRv"
# Out:
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PL3BHAe3X0TGvUFmKDKPnHSf5s_HSv3HRv
# [youtube:tab] PL3BHAe3X0TGvUFmKDKPnHSf5s_HSv3HRv: Downloading webpage
# [youtube:tab] PL3BHAe3X0TGvUFmKDKPnHSf5s_HSv3HRv: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Skibidi Toilet Zombie Universe (All Episodes)
# [youtube:tab] PL3BHAe3X0TGvUFmKDKPnHSf5s_HSv3HRv page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# [youtube:tab] PL3BHAe3X0TGvUFmKDKPnHSf5s_HSv3HRv page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (2/3)...
# [youtube:tab] PL3BHAe3X0TGvUFmKDKPnHSf5s_HSv3HRv page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (3/3)...
# [youtube:tab] PL3BHAe3X0TGvUFmKDKPnHSf5s_HSv3HRv page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Giving up after 3 retries
# ...

# %%
# !ls sus/
# Out:
# '01-skibidi zombie universe 01 ( New Virus).webm'
# '02-skibidi zombie universe 02  ( New Virus).webm'
# '03-skibidi zombie universe 03  ( New Virus).webm'
# '04-skibidi zombie universe 04  ( New Virus).webm'
# '05-skibidi zombie universe 05  ( New Virus).webm'
# '06-skibidi zombie universe 06  ( New Virus).webm'
# '07-skibidi zombie universe 07  ( New Virus).webm'
# '08-skibidi zombie universe 08  ( New Virus).webm'
# '09-skibidi zombie universe 09  ( New Virus).webm'
# '10-skibidi zombie universe 10  ( New Virus).webm'
# '11-skibidi toilet zombie universe 11  ( New Virus).webm'
# '12-skibidi toilet zombie universe 12  ( New Virus).webm'
# '13-skibidi toilet zombie universe 13 ( New Virus).webm'
# '14-skibidi toilet zombie universe 14 ( New Virus).webm'
# '15-skibidi toilet zombie universe 15 ( New Virus).webm'
# '16-skibidi toilet zombie universe 16 ( New Virus).webm'
# '17-skibidi toilet zombie universe 17 ( New Virus).webm'
# ...

# %%
 # !ffmpeg -f concat -safe 0 -i sus/file.txt -c copy output.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !curl --progress-bar -o o -T "output.mp4" -H "Authorization: Bearer AA3iByB9Fak=" https://w.buzzheavier.com/ && cat o && rm o
# Out:
# ############################################################################################# 100.0%
# {"id":"GJ1-adit4AA="}
