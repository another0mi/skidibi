# %%
# !sudo apt update && sudo apt upgrade
# !sudo apt autoremove
# !pip install yt-dlp
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 4 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# ...

# %%
# !yt-dlp -o "sus/%(playlist_index)s-%(title)s.%(ext)s" "https://youtube.com/playlist?list=PLpYDrDBEbI_nQTkKLRk0L3VfitNhVZIH_&si=6hTYjBkNBlhpZGwm"
# Out:
# [youtube:tab] Extracting URL: https://youtube.com/playlist?list=PLpYDrDBEbI_nQTkKLRk0L3VfitNhVZIH_&si=6hTYjBkNBlhpZGwm
# [youtube:tab] PLpYDrDBEbI_nQTkKLRk0L3VfitNhVZIH_: Downloading webpage
# [youtube:tab] PLpYDrDBEbI_nQTkKLRk0L3VfitNhVZIH_: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: skibidi toilet - season 1/23 (all episodes )
# [youtube:tab] PLpYDrDBEbI_nQTkKLRk0L3VfitNhVZIH_ page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# [youtube:tab] PLpYDrDBEbI_nQTkKLRk0L3VfitNhVZIH_ page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (2/3)...
# [youtube:tab] PLpYDrDBEbI_nQTkKLRk0L3VfitNhVZIH_ page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (3/3)...
# [youtube:tab] PLpYDrDBEbI_nQTkKLRk0L3VfitNhVZIH_ page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Giving up after 3 retries
# ...

# %%
# !ls sus/
# Out:
# '01-skibidi toilet - season 1 (all episodes).webm'
# '02-skibidi toilet - season 2 (all episodes).webm'
# '03-skibidi toilet - season 3 (all episodes).webm'
# '04-skibidi toilet - season 4 (all episodes).webm'
# '05-skibidi toilet - season 5 (all episodes).webm'
# '06-skibidi toilet - season 6 (all episodes).webm'
# '07-skibidi toilet - season 7 (all episodes).webm'
# '08-skibidi toilet - season 8 (all episodes).webm'
# '09-skibidi toilet - season 9 (all episodes).webm'
# '10-skibidi toilet - season 10 (all episodes).webm'
# '11-skibidi toilet - season 11 (all episodes).webm'
# '12-skibidi toilet - season 12 (all episodes).webm'
# '13-skibidi toilet - season 13 (all episodes).webm'
# '14-skibidi toilet - season 14 (all episodes).webm'
# '15-skibidi toilet - season 15 (all episodes).webm'
# '16-skibidi toilet - season 16 (all episodes).webm'
# '17-skibidi toilet - season 17 (all episodes).webm'
# '18-skibidi toilet - season 18 (all episodes).webm'
# ...

# %%
 # !ffmpeg -f concat -safe 0 -i sus/filenames.txt -c copy output.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !curl --progress-bar -o o -T "output.mp4" -H "Authorization: Bearer AA3iByB9Fak=" https://w.buzzheavier.com/t/output.mp4 && cat o && rm o
# Out:
# ############################################################################################# 100.0%
# {"id":"GJmqdwN-0AA="}
